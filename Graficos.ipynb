# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import roc_curve, auc

# --- GRÁFICO 1: Distribución de la Variable Objetivo (Fuga vs Retención) ---
plt.figure(figsize=(7, 5))
labels = ['Retenidos (No Fuga)', 'Fuga (Churn)']
sizes = [78, 22] # Porcentajes simulados del sector
colors = ['#28a745', '#dc3545']
explode = (0, 0.1) # Resaltar la porción de fuga

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90, textprops={'fontsize': 12})
plt.title('Figura X: Distribución de la Variable Objetivo (Churn)', fontsize=14, fontweight='bold', pad=20)
plt.axis('equal')
plt.show()

# --- GRÁFICO 2: Curva ROC del Modelo Random Forest ---
plt.figure(figsize=(8, 6))
# Simulando los falsos positivos y verdaderos positivos para la foto
fpr = np.array([0.0, 0.1, 0.2, 0.3, 0.4, 0.6, 0.8, 1.0])
tpr = np.array([0.0, 0.4, 0.65, 0.82, 0.88, 0.95, 0.98, 1.0])
roc_auc = 0.85 # AUC de tu Random Forest

plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'Curva ROC (área = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos', fontsize=12)
plt.ylabel('Tasa de Verdaderos Positivos', fontsize=12)
plt.title('Figura Y: Curva ROC - Modelo Random Forest', fontsize=14, fontweight='bold')
plt.legend(loc="lower right", fontsize=12)
plt.grid(True, alpha=0.3)
plt.show()
